# %%
import numpy as np 
import pandas as pd 

from sklearn import preprocessing
import matplotlib.pyplot as plt 
plt.rc("font", size=14) #dictionary objects
import seaborn as sns
sns.set(style="white") #white background style for seaborn plots
sns.set(style="whitegrid", color_codes=True)

import warnings
warnings.simplefilter(action='ignore')
from sklearn.metrics import accuracy_score
from sklearn.metrics import make_scorer
from sklearn import metrics

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV

# %%
df_train = pd.read_csv('/content/train.csv')

# %%
df_train.isnull().sum()
# Out:
# x1     109
# x2      34
# x3      56
# x4      93
# x5      60
# x6     118
# x7      81
# x8     135
# x9       0
# x10     79
# x11     17
# x12     12
# x13    130
# x14    124
# x15    107
# x16     93
# x17    125
# x18     20
# x19    145
# x20    126
# y        0
# dtype: int64

# %%
plt.subplots(figsize=(10, 5))
sns.heatmap(X.corr(), annot=True, cmap="RdYlGn")
plt.show()

# %%
corr = df_train.corr()
sns.heatmap(round(corr,1), annot=True)
plt.show()

# %% [markdown]
# # **Cleansing Data**

# %% [markdown]
# replace null value with median

# %%
x1g = df_train['x1'].hist(bins=1)
df_train['x1'].plot(kind = 'density', color = 'teal')
x1g.set(xlabel ='x1')
plt.xlim(-30,1)
plt.show()

# %%
x1_medi = df_train['x1'].median(skipna = True)
x1_medi
df_train['x1'] = df_train['x1'].fillna(x1_medi)
x2ot = df_train['x2'][df_train['x2'] == -624.6532519]
x2ot
x2ot1 = df_train['x2'][df_train['x2'] >= 37]
x2ot1
df_train = df_train.drop(index = 2742 ,axis=0)
df_train = df_train.drop(index = 478 ,axis=0)
x2_medi = df_train['x2'].median(skipna = True)
x2_medi
df_train['x2'] = df_train['x2'].fillna(x2_medi)
x3_medi = df_train['x3'].median(skipna = True)
x3_medi
df_train['x3'] = df_train['x3'].fillna(x3_medi)
x4ot1 = df_train['x4'][df_train['x4'] <= 1]
x4ot1
df_train = df_train.drop(index = 5863  ,axis=0)
x4_medi = df_train['x4'].median(skipna = True)
x4_medi
df_train['x4'] = df_train['x4'].fillna(x4_medi)
x5_medi = df_train['x5'].median(skipna = True)
x5_medi
df_train['x5'] = df_train['x5'].fillna(x5_medi)
x6_medi = df_train['x6'].median(skipna = True)
df_train['x6'] = df_train['x6'].fillna(x6_medi)
x7ot1 = df_train['x7'][df_train['x7'] > 20]
x7ot1
df_train = df_train.drop(index = 7168  ,axis=0)
x7_medi = df_train['x7'].median(skipna = True)
x7_medi
df_train['x7'] = df_train['x7'].fillna(x7_medi)
x8ot1 = df_train['x8'][df_train['x8'] <0]
x8ot1
df_train = df_train.drop(index = 1849  ,axis=0)
x8_medi = df_train['x8'].median(skipna = True)
x8_medi
df_train['x8'] = df_train['x8'].fillna(x8_medi)
x9_medi = df_train['x9'].median(skipna = True)
x9_medi
df_train['x9'] = df_train['x9'].fillna(x9_medi)
x10_medi = df_train['x10'].median(skipna = True)
x10_medi
df_train['x10'] = df_train['x10'].fillna(x10_medi)
x11_medi = df_train['x11'].median(skipna = True)
x11_medi
df_train['x11'] = df_train['x11'].fillna(x11_medi)
x12_medi = df_train['x12'].median(skipna = True)
x12_medi
df_train['x12'] = df_train['x12'].fillna(x12_medi)
x13_medi = df_train['x13'].median(skipna = True)
x13_medi
df_train['x13'] = df_train['x13'].fillna(x13_medi)
x14ot1 = df_train['x14'][df_train['x14'] <1]
x14ot1
df_train = df_train.drop(index = 2768 ,axis=0)
df_train = df_train.drop(index = 2859 ,axis=0)
df_train = df_train.drop(index = 5713  ,axis=0)
x14_medi = df_train['x14'].median(skipna = True)
x14_medi
df_train['x14'] = df_train['x14'].fillna(x14_medi)
x15_medi = df_train['x15'].median(skipna = True)
x15_medi
df_train['x15'] = df_train['x15'].fillna(x15_medi)
x16_medi = df_train['x16'].median(skipna = True)
x16_medi
df_train['x16'] = df_train['x16'].fillna(x16_medi)
x17_medi = df_train['x17'].median(skipna = True)
x17_medi
df_train['x17'] = df_train['x17'].fillna(x17_medi)
x18_medi = df_train['x18'].median(skipna = True)
x18_medi
df_train['x18'] = df_train['x18'].fillna(x18_medi)
x19_medi = df_train['x19'].median(skipna = True)
x19_medi
df_train['x19'] = df_train['x19'].fillna(x19_medi)
x20_medi = df_train['x20'].median(skipna = True)
x20_medi
df_train['x20'] = df_train['x20'].fillna(x20_medi)

# %%
df_train.isnull().sum()
# Out:
# x1     0
# x2     0
# x3     0
# x4     0
# x5     0
# x6     0
# x7     0
# x8     0
# x9     0
# x10    0
# x11    0
# x12    0
# x13    0
# x14    0
# x15    0
# x16    0
# x17    0
# x18    0
# x19    0
# x20    0
# y      0
# dtype: int64

# %% [markdown]
# # **Feature Selection**

# %%
feature_cols= ['x1','x2','x3','x4','x5','x6','x7','x8','x9','x10','x11','x12','x13','x14','x15','x16','x17','x18','x19','x20']
X = df_train[feature_cols]
y = df_train.y

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

# %%
from sklearn.feature_selection import RFECV
rfecv = RFECV(estimator=RandomForestClassifier(), step=1, cv=5, scoring='accuracy')
rfecv.fit(X, y)
# Out:
# RFECV(cv=5, estimator=RandomForestClassifier(), scoring='accuracy')

# %%
print("Optimal number of features: %d" % rfecv.n_features_)
print('Selected features: %s' % list(X.columns[rfecv.support_]))
# Out:
# Optimal number of features: 10
# Selected features: ['x2', 'x3', 'x6', 'x7', 'x8', 'x9', 'x10', 'x12', 'x14', 'x15']

# %% [markdown]
# # **Normalize Data**

# %%
x_se_col = ['x2', 'x3', 'x6', 'x7', 'x8', 'x9', 'x10', 'x12', 'x14', 'x15','x19']
x_se_col = df_train[x_se_col]
y = df_train.y
x_se_col.head()
# Out:
#            x2         x3          x6          x7         x8            x9  \
# 0 -166.447703  57.634618  773.535357 -425.516507  19.541551  102333.24180
# 1 -175.583196  61.413742  592.665369 -154.993322  17.165756   56410.00878
# 2 -266.301983  43.228042  912.741203 -337.001477  18.362978   37204.35472
# 3 -228.458742  45.440429  834.109486 -297.096954  16.375756   54967.23130
# 4 -345.861627  37.470283  634.255353 -243.072126  16.785630   62397.51981
#
#          x10       x12         x14        x15         x19
# 0  37.515512  1.177903   65.320993  10.856422  194.151039
# 1  33.667832  6.288225  124.629610  19.519498  159.152326
# 2  24.194495  5.241047  136.536890  16.824492  148.690528
# 3  20.578061  2.316119  118.295834  19.972844  310.539447
# 4  39.815572  5.366404   61.414626  15.990853  241.868249

# %%
from sklearn import preprocessing
import numpy as np


# normalize the data attributes
normalized = preprocessing.normalize(x_se_col)
print("Normalized Data = ", normalized)

normalizer = preprocessing.Normalizer().fit(x_se_col)  # fit does nothing
normalizer.transform(x_se_col)
# Out:
# Normalized Data =  [[-0.00162646  0.00056318  0.00755868 ...  0.00063829  0.00010608
#    0.00189717]
#  [-0.0031124   0.00108863  0.01050564 ...  0.0022092   0.000346
#    0.00282115]
#  [-0.00715507  0.00116146  0.02452378 ...  0.00366851  0.00045205
#    0.00399506]
#  ...
#  [-0.00218964  0.00094619  0.00810007 ...  0.00075556  0.00024459
#    0.00344202]
#  [-0.01137298  0.00095021  0.0445866  ...  0.00866592  0.00074854
#    0.01745286]
#  [-0.00394167  0.0005901   0.00998292 ...  0.00181373  0.00024566
#    0.00350074]]
# array([[-0.00162646,  0.00056318,  0.00755868, ...,  0.00063829,
#          0.00010608,  0.00189717],
#        [-0.0031124 ,  0.00108863,  0.01050564, ...,  0.0022092 ,
#          0.000346  ,  0.00282115],
#        [-0.00715507,  0.00116146,  0.02452378, ...,  0.00366851,
#          0.00045205,  0.00399506],
#        ...,
#        [-0.00218964,  0.00094619,  0.00810007, ...,  0.00075556,
#          0.00024459,  0.00344202],
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_se_col, y, test_size=0.30, stratify= y ,random_state=50)

# %%
sc=StandardScaler()
#X_train, X_test
scaler = sc.fit(X_train)
trainX_scaled = scaler.transform(X_train)
testX_scaled = scaler.transform(X_test)

# %%
X_scaled = scaler.transform(x_se_col)

# %%
#mlp_clf = MLPClassifier(hidden_layer_sizes=(150,100,50),
                        #max_iter = 300,activation = 'relu',
                        #solver = 'adam')
#mlp_clf = MLPClassifier(hidden_layer_sizes=(150,100,50),
                        #max_iter = 300,activation = 'relu',
                        #solver = 'adam')

# %%
mlp_clf = MLPClassifier(hidden_layer_sizes=(1550,800,500),
                        max_iter = 300, activation = 'relu',
                        solver = 'adam')

# %%
#mlp_clf = MLPClassifier(hidden_layer_sizes=(2000,1000,800),
                        max_iter = 300,activation = 'relu',
                        solver = 'adam')

# %%
mlp_clf.fit(trainX_scaled, y_train)
y_pred_ = mlp_clf.predict(testX_scaled)
print(metrics.classification_report(y_test, y_pred_))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1681
#            1       0.98      0.97      0.97       567
#
#     accuracy                           0.99      2248
#    macro avg       0.98      0.98      0.98      2248
# weighted avg       0.99      0.99      0.99      2248

# %%
mlp_clf.fit(X_scaled,y)
# Out:
# MLPClassifier(hidden_layer_sizes=(1550, 800, 500), max_iter=300)

# %%
y_pred_ = mlp_clf.predict(X_scaled)

# %%
print(metrics.classification_report(y, y_pred_))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5601
#            1       1.00      1.00      1.00      1891
#
#     accuracy                           1.00      7492
#    macro avg       1.00      1.00      1.00      7492
# weighted avg       1.00      1.00      1.00      7492

# %% [markdown]
# # **Predict**

# %%
df_test = pd.read_csv('/content/test.csv')
df_test.head()
# Out:
#           x1          x2         x3        x4        x5           x6  \
# 0 -14.880285 -413.657030  17.037929  5.627481  6.262187   704.164878
# 1 -13.987087 -235.197680  53.670585  4.743702  4.670301  1226.941573
# 2 -11.764850 -192.880170  38.687566  5.606648  4.147060   940.690132
# 3 -10.790193 -204.849932  50.837951  5.934410  5.310772   794.581702
# 4 -17.113392 -141.457819  53.246627  5.939751  5.631022   543.441438
#
#            x7         x8           x9        x10        x11       x12  \
# 0 -269.815659  13.503896  60805.03782  31.065906   5.625478  5.150013
# 1 -184.656449   7.034055  55445.68723  15.189238  15.746002  3.880180
# 2 -182.564985  17.218596  31562.61815  34.769586  12.766144  4.885215
# 3 -245.911853   9.936746  47299.76010  25.565751  14.068207  7.156563
# 4 -302.081360  21.861266  66725.53006  34.796947  13.834198  4.743589
#
#            x13         x14        x15        x16         x17        x18  \
# ...

# %%
x_test_col = ['x2', 'x3', 'x6', 'x7', 'x8', 'x9', 'x10', 'x12', 'x14', 'x15','x19']
x_test_col = df_test[x_test_col]

x_test_col.head()
# Out:
#            x2         x3           x6          x7         x8           x9  \
# 0 -413.657030  17.037929   704.164878 -269.815659  13.503896  60805.03782
# 1 -235.197680  53.670585  1226.941573 -184.656449   7.034055  55445.68723
# 2 -192.880170  38.687566   940.690132 -182.564985  17.218596  31562.61815
# 3 -204.849932  50.837951   794.581702 -245.911853   9.936746  47299.76010
# 4 -141.457819  53.246627   543.441438 -302.081360  21.861266  66725.53006
#
#          x10       x12         x14        x15         x19
# 0  31.065906  5.150013  174.281276  19.959450  232.140628
# 1  15.189238  3.880180   32.216142  17.054081  267.024627
# 2  34.769586  4.885215  181.736690  20.479688  115.762593
# 3  25.565751  7.156563  127.570137  20.904829  213.574163
# 4  34.796947  4.743589  119.269139  19.826086  263.709173

# %%
normalized = preprocessing.normalize(x_test_col)
print("Normalized Data = ", normalized)

normalizer = preprocessing.Normalizer().fit(x_test_col)  # fit does nothing
normalizer.transform(x_test_col)
# Out:
# Normalized Data =  [[-0.00680225  0.00028017  0.01157941 ...  0.00286591  0.00032822
#    0.00381736]
#  [-0.0042408   0.00096772  0.0221227  ...  0.00058088  0.0003075
#    0.00481466]
#  [-0.00610795  0.00122512  0.02978891 ...  0.00575507  0.00064853
#    0.00366586]
#  ...
#  [-0.00144502  0.00069148  0.00665674 ...  0.00086909  0.00019842
#    0.00471595]
#  [-0.00563279  0.00095809  0.0205955  ...  0.00131052  0.00020006
#    0.00661676]
#  [-0.00527151  0.00145074  0.03037436 ...  0.00525905  0.00069693
#    0.00780546]]
# array([[-0.00680225,  0.00028017,  0.01157941, ...,  0.00286591,
#          0.00032822,  0.00381736],
#        [-0.0042408 ,  0.00096772,  0.0221227 , ...,  0.00058088,
#          0.0003075 ,  0.00481466],
#        [-0.00610795,  0.00122512,  0.02978891, ...,  0.00575507,
#          0.00064853,  0.00366586],
#        ...,
#        [-0.00144502,  0.00069148,  0.00665674, ...,  0.00086909,
#          0.00019842,  0.00471595],
# ...

# %%
test_scaled = scaler.transform(x_test_col)

# %%
predict = mlp_clf.predict(test_scaled)  
fields = ['id','Expected']
df = pd.DataFrame()
id = list(range(1,2501))
df['id']=pd.Series(id)
df['Expected']=pd.Series(predict)
df.to_csv('submit_NN4.csv', index=False)
